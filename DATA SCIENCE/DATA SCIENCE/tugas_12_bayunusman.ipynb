# %% [markdown]
# <h2>Soal 1:</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note: warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

# %%
#code here
plt.figure(figsize=(9,6))
plt.plot(x, np.cos(x),color = 'yellow',linestyle='--', label='cos')
plt.plot(x, np.cos(x)*3,color = 'green',linestyle='--', label='cos3')
plt.plot(x, np.sin(x-90),color = 'blue',linestyle='-.', label='sin')
plt.plot(x, np.sin(x)*2,color = 'red',label='sin2')
plt.legend(loc='center')
# memberikan data kedalam axis
plt.title('Grafik cos sin')

#memberikan warna
# menggunakan nama dari warnanya

plt.show()
plt.show()

# %% [markdown]
# Expected Result:
#
# ![alt text](https://drive.google.com/uc?id=1XRcfWyiWLDmriw7s7U4fTn5Gs6s2qf5o)
